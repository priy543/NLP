# %%
import nltk
import string
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')

articles = [
    "Artificial intelligence is transforming healthcare and education systems",
    "AI and machine learning are the future of technology and innovation",
    "Healthcare systems are improving with artificial intelligence solutions",
    "Education technology is growing rapidly with AI based tools"
]

text = " ".join(articles).lower()

text = text.translate(str.maketrans('', '', string.punctuation))

tokens = word_tokenize(text)

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

freq_dist = Counter(filtered_tokens)

vocabulary = set(filtered_tokens)

top5 = freq_dist.most_common(5)

ttr = len(vocabulary) / len(filtered_tokens)

topics = {
    "AI": ["artificial", "intelligence", "ai", "machine", "learning"],
    "Healthcare": ["healthcare", "systems"],
    "Education": ["education"],
    "Technology": ["technology", "innovation", "tools"]
}

topic_scores = {}

for topic, words in topics.items():
    score = sum(freq_dist[word] for word in words if word in freq_dist)
    topic_scores[topic] = score

dominant_topic = max(topic_scores, key=topic_scores.get)

print("Filtered Tokens:")
print(filtered_tokens)

print("\nWord Frequency Distribution:")
print(freq_dist)

print("\nVocabulary:")
print(vocabulary)

print("\nTop 5 Frequent Words:")
print(top5)

print("\nType-Token Ratio (TTR):")
print(round(ttr, 3))

print("\nTopic Scores:")
print(topic_scores)

print("\nDominant Topic:")
print(dominant_topic)

words = list(freq_dist.keys())
counts = list(freq_dist.values())

plt.figure(figsize=(10, 5))
plt.bar(words, counts)
plt.title("Word Frequency Distribution")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Filtered Tokens:
# ['artificial', 'intelligence', 'transforming', 'healthcare', 'education', 'systems', 'ai', 'machine', 'learning', 'future', 'technology', 'innovation', 'healthcare', 'systems', 'improving', 'artificial', 'intelligence', 'solutions', 'education', 'technology', 'growing', 'rapidly', 'ai', 'based', 'tools']
#
# Word Frequency Distribution:
# Counter({'artificial': 2, 'intelligence': 2, 'healthcare': 2, 'education': 2, 'systems': 2, 'ai': 2, 'technology': 2, 'transforming': 1, 'machine': 1, 'learning': 1, 'future': 1, 'innovation': 1, 'improving': 1, 'solutions': 1, 'growing': 1, 'rapidly': 1, 'based': 1, 'tools': 1})
#
# Vocabulary:
# {'transforming', 'growing', 'based', 'systems', 'tools', 'improving', 'innovation', 'solutions', 'future', 'artificial', 'intelligence', 'machine', 'ai', 'technology', 'education', 'rapidly', 'healthcare', 'learning'}
#
# Top 5 Frequent Words:
# [('artificial', 2), ('intelligence', 2), ('healthcare', 2), ('education', 2), ('systems', 2)]
#
# Type-Token Ratio (TTR):
# 0.72
#
# Topic Scores:
# {'AI': 8, 'Healthcare': 4, 'Education': 2, 'Technology': 4}
#
# Dominant Topic:
# AI
